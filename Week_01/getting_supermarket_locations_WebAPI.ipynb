# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# C:\Users\n-win\Desktop\ZHAW\Classes\Data Analytics\data_analytics\Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3469, 278)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.postid tags.diet:local tags.payment:account_cards  \
# 0         NaN             NaN                        NaN
# 1         NaN             NaN                        NaN
# 2         NaN             NaN                        NaN
# 3         NaN             NaN                        NaN
# 4         NaN             NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#   tags.recycling:low_energy_bulbs tags.opening_hours:cafe tags.name:zh-Hans  \
# 0                             NaN                     NaN               NaN
# 1                             NaN                     NaN               NaN
# 2                             NaN                     NaN               NaN
# 3                             NaN                     NaN               NaN
# 4                             NaN                     NaN               NaN
#
#   tags.panoramax
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 278 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12999bc539d866bf6ec70642d18d6272 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12999bc539d866bf6ec70642d18d6272&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12999bc539d866bf6ec70642d18d6272 = L.map(
#                 &quot;map_12999bc539d866bf6ec70642d18d6272&quot;,
#                 {
#                     center: [47.010083662850086, 8.004460116721582],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_12999bc539d866bf6ec70642d18d6272);
#
#
#
#
#
#             var tile_layer_36be0311cfa2d00445c38b61a7fc3eab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_36be0311cfa2d00445c38b61a7fc3eab.addTo(map_12999bc539d866bf6ec70642d18d6272);
#
#
#             var marker_a2710f38dd1a9a48b9f333c1110aef93 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_12999bc539d866bf6ec70642d18d6272);
#
#
#         var popup_afbe0b8a6a09b76620474af2601c18c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d427f8d7b26006be98c57e39e7c51094 = $(`&lt;div id=&quot;html_d427f8d7b26006be98c57e39e7c51094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_afbe0b8a6a09b76620474af2601c18c0.setContent(html_d427f8d7b26006be98c57e39e7c51094);
#
#
#
#         marker_a2710f38dd1a9a48b9f333c1110aef93.bindPopup(popup_afbe0b8a6a09b76620474af2601c18c0)
#         ;
#
#
#
#
#             var marker_df646117732d9e80774561a794d72cad = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_12999bc539d866bf6ec70642d18d6272);
#
#
#         var popup_d15cec909fd7be9884e11860935f9c59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47264539e505dae01838c31e1365d474 = $(`&lt;div id=&quot;html_47264539e505dae01838c31e1365d474&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_d15cec909fd7be9884e11860935f9c59.setContent(html_47264539e505dae01838c31e1365d474);
#
#
#
#         marker_df646117732d9e80774561a794d72cad.bindPopup(popup_d15cec909fd7be9884e11860935f9c59)
#         ;
#
#
#
#
#             var marker_4cef619418abd1da6cc416beaa95d5c5 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_12999bc539d866bf6ec70642d18d6272);
#
#
#         var popup_94d4de91feb9dc3b476e9a53691daf92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef52632c0c8e02b462da26603d33bf1c = $(`&lt;div id=&quot;html_ef52632c0c8e02b462da26603d33bf1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_94d4de91feb9dc3b476e9a53691daf92.setContent(html_ef52632c0c8e02b462da26603d33bf1c);
#
#
#
#         marker_4cef619418abd1da6cc416beaa95d5c5.bindPopup(popup_94d4de91feb9dc3b476e9a53691daf92)
#         ;
#
#
#
#
#             var marker_d602bcc1fe2fb09084e9337b63ce959d = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_12999bc539d866bf6ec70642d18d6272);
#
#
#         var popup_93d47db7acf3f0c42e56db875b2b7ba7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5bcf1e9c7bf860ef35b4db770975b0e = $(`&lt;div id=&quot;html_d5bcf1e9c7bf860ef35b4db770975b0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_93d47db7acf3f0c42e56db875b2b7ba7.setContent(html_d5bcf1e9c7bf860ef35b4db770975b0e);
#
#
#
#         marker_d602bcc1fe2fb09084e9337b63ce959d.bindPopup(popup_93d47db7acf3f0c42e56db875b2b7ba7)
#         ;
#
#
#
#
#             var marker_aa9c8b135e651af352b22f89e07426ca = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_12999bc539d866bf6ec70642d18d6272);
#
#
#         var popup_1d795d8ebf64c5ab76db5561d04446e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a555d1037d483a4e4114864410730048 = $(`&lt;div id=&quot;html_a555d1037d483a4e4114864410730048&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_1d795d8ebf64c5ab76db5561d04446e1.setContent(html_a555d1037d483a4e4114864410730048);
#
#
#
#         marker_aa9c8b135e651af352b22f89e07426ca.bindPopup(popup_1d795d8ebf64c5ab76db5561d04446e1)
#         ;
#
#
#
#
#             var marker_afdc344c41cba257db3f50da53a156f7 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2025-11-07 23:13:53
# Python Version: 3.10.5
# -----------------------------------
